# %% [markdown]
# # Tree Processing
# For this study, trees were modeled as if they were 'buildings' but with a high wall absorption coefficient.

# %% [markdown]
# # Glasgow Tree Processing
# Data:  https://data.ubdc.ac.uk/dataset/96ad6074-acff-49fc-95da-473fe6da4205

# %% [markdown]
# ## Reading all the files into 1 gdf

# %%
import geopandas as gpd
import pandas as pd
import glob
import os

# Folder containing the shapefiles
folder_path = r"C:\Users\ibk1\NoiseModelling\Glasgow\env_data\tree_volume\tree_canopy_products\treetop_location"

# Get a list of all shapefiles in the folder
shapefiles = glob.glob(os.path.join(folder_path, "*.shp"))

# Read and process each shapefile
gdfs = [gpd.read_file(shp).set_crs(epsg=27700, allow_override=True) for shp in shapefiles]

# Merge all shapefiles into a single GeoDataFrame
merged_gdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))

# Create a 0.5-meter buffer around each point
merged_gdf["geometry"] = merged_gdf.geometry.buffer(1) # This sets the average diameter to 1 (0.5m, 50cm radius), might be too large 

print(f"Merged and buffered gdf created!")
# Out:
# Merged and buffered gdf created!

# %%
len(merged_gdf)
# Out:
# 1339588

# %%
merged_gdf.head()
# Out:
#      HEIGHT                                           THE_GEOM    G
# 0  9.662998  POLYGON ((249624.25 659999.865, 249624.245 659...  0.1
# 1  6.701000  POLYGON ((249627.75 659999.865, 249627.745 659...  0.1
# 2  9.841003  POLYGON ((249501.25 659999.365, 249501.245 659...  0.1
# 3  6.231998  POLYGON ((249532.25 659999.365, 249532.245 659...  0.1
# 4  4.015003  POLYGON ((249982.75 659999.365, 249982.745 659...  0.1

# %%
merged_gdf["HEIGHT"].median()
# Out:
# 9.642999649047852

# %%
merged_gdf.columns
merged_gdf = merged_gdf[['Z', "geometry"]]
merged_gdf = merged_gdf[['Z', 'geometry']].rename(columns={'Z': 'HEIGHT', 'geometry': 'THE_GEOM'})
merged_gdf["G"] = .1 # Wall absorption

# %%
merged_gdf = merged_gdf.set_geometry("THE_GEOM")

# %%
merged_gdf.head()
# Out:
#      HEIGHT                                           THE_GEOM    G
# 0  9.662998  POLYGON ((249624.25 659999.865, 249624.245 659...  0.1
# 1  6.701000  POLYGON ((249627.75 659999.865, 249627.745 659...  0.1
# 2  9.841003  POLYGON ((249501.25 659999.365, 249501.245 659...  0.1
# 3  6.231998  POLYGON ((249532.25 659999.365, 249532.245 659...  0.1
# 4  4.015003  POLYGON ((249982.75 659999.365, 249982.745 659...  0.1

# %%
merged_gdf.to_file(r"C:\Users\ibk1\NoiseModelling\Glasgow\noisemodelling_outputs\summerbuildings\trees.geojson")

# %% [markdown]
# ## Combining with Buildings

# %%
import geopandas as gpd
buildings = gpd.read_file(r"C:\Users\ibk1\NoiseModelling\Glasgow\noisemodelling_outputs\Round2\ready_input_buildings_cleaned.geojson") # Changed to a different srid 
buildings.columns
# Out:
# Index(['PK', 'HEIGHT', 'geometry'], dtype='object')

# %%
len(buildings)
# Out:
# 61466

# %%
test = buildings[buildings["HEIGHT"] < 0]

# %%
test.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e53579c792a1f99bafc8efdbe0d1f500 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e53579c792a1f99bafc8efdbe0d1f500&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e53579c792a1f99bafc8efdbe0d1f500 = L.map(
#                 &quot;map_e53579c792a1f99bafc8efdbe0d1f500&quot;,
#                 {
#                     center: [55.862990374434375, -4.2973949025455],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_e53579c792a1f99bafc8efdbe0d1f500);
#
#
#
#
#
#             var tile_layer_f5e9f4593772d673087ef9a456c40212 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f5e9f4593772d673087ef9a456c40212.addTo(map_e53579c792a1f99bafc8efdbe0d1f500);
#
#
#             map_e53579c792a1f99bafc8efdbe0d1f500.fitBounds(
#                 [[55.85249552933223, -4.345740896872706], [55.87348521953651, -4.249048908218294]],
#                 {}
#             );
#
#
#         function geo_json_996bdfc0ec8e162fa7d18dcd8756974f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_996bdfc0ec8e162fa7d18dcd8756974f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_996bdfc0ec8e162fa7d18dcd8756974f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_996bdfc0ec8e162fa7d18dcd8756974f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_996bdfc0ec8e162fa7d18dcd8756974f_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_996bdfc0ec8e162fa7d18dcd8756974f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_996bdfc0ec8e162fa7d18dcd8756974f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_996bdfc0ec8e162fa7d18dcd8756974f = L.geoJson(null, {
#                 onEachFeature: geo_json_996bdfc0ec8e162fa7d18dcd8756974f_onEachFeature,
#
#                 style: geo_json_996bdfc0ec8e162fa7d18dcd8756974f_styler,
#                 pointToLayer: geo_json_996bdfc0ec8e162fa7d18dcd8756974f_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_996bdfc0ec8e162fa7d18dcd8756974f_add (data) {
#             geo_json_996bdfc0ec8e162fa7d18dcd8756974f
#                 .addData(data);
#         }
#             geo_json_996bdfc0ec8e162fa7d18dcd8756974f_add({&quot;bbox&quot;: [-4.345740896872706, 55.85249552933223, -4.249048908218294, 55.87348521953651], &quot;features&quot;: [{&quot;bbox&quot;: [-4.331487703077486, 55.86509769776358, -4.331248392429534, 55.86513403069973], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-4.331248392429534, 55.86512078266532], [-4.331252443447032, 55.86509769776358], [-4.331487703077486, 55.86511094276408], [-4.3314834925502135, 55.86513403069973], [-4.331248392429534, 55.86512078266532]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;833&quot;, &quot;properties&quot;: {&quot;HEIGHT&quot;: -1.25699996948, &quot;PK&quot;: 835}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-4.324007786

# %%
buildings.columns
# Out:
# Index(['PK', 'HEIGHT', 'geometry'], dtype='object')

# %%
buildings.head()
# Out:
#    PK     HEIGHT                                           geometry
# 0   1  53.230999  POLYGON ((251523.28 672118.14, 251519.33 67210...
# 1   2  52.737000  POLYGON ((251502.32 672114.01, 251503.54 67211...
# 2   3  53.498001  POLYGON ((251539.19 672102.32, 251530.49 67209...
# 3   4  52.759998  POLYGON ((251488.03 672078.03, 251483.36 67208...
# 4   5  49.250000  POLYGON ((251403.66 672074.72, 251402.21 67207...

# %%
# Changing geometry names to match case with noisemodelling 
#buildings = buildings[['Ground_Z', "geometry"]]
#buildings = buildings[['Ground_Z', 'geometry']].rename(columns={'Ground_Z': 'HEIGHT', 'geometry': 'geometry'})

# %%
buildings["G"] = .9 # Wall absorption

# %%
buildings.head()
# Out:
#    PK     HEIGHT                                           geometry    G
# 0   1  53.230999  POLYGON ((251523.28 672118.14, 251519.33 67210...  0.9
# 1   2  52.737000  POLYGON ((251502.32 672114.01, 251503.54 67211...  0.9
# 2   3  53.498001  POLYGON ((251539.19 672102.32, 251530.49 67209...  0.9
# 3   4  52.759998  POLYGON ((251488.03 672078.03, 251483.36 67208...  0.9
# 4   5  49.250000  POLYGON ((251403.66 672074.72, 251402.21 67207...  0.9

# %%
trees_clean = gpd.read_file(r"C:\Users\ibk1\NoiseModelling\Glasgow\noisemodelling_outputs\summerbuildings\trees_clean.geojson")

# %%
trees_clean.head()
# Out:
#    PK    HEIGHT                                           geometry
# 0   1  9.662998  POLYGON ((249623.81 659999.03, 249623.15 65999...
# 1   2  6.701000  POLYGON ((249627.75 659999.77, 249627.31 65999...
# 2   3  9.841003  POLYGON ((249500.81 659998.53, 249500.15 65999...
# 3   4  6.231998  POLYGON ((249532.25 659999.27, 249531.81 65999...
# 4   5  4.015003  POLYGON ((249982.75 659999.27, 249982.31 65999...

# %%
trees_clean["G"] = .1 # Wall absorption

# %%
combined_gdf = gpd.GeoDataFrame(pd.concat([trees_clean, buildings], ignore_index=True))

# %%
combined_gdf.head()
# Out:
#    PK    HEIGHT                                           geometry    G
# 0   1  9.662998  POLYGON ((249623.81 659999.03, 249623.15 65999...  0.1
# 1   2  6.701000  POLYGON ((249627.75 659999.77, 249627.31 65999...  0.1
# 2   3  9.841003  POLYGON ((249500.81 659998.53, 249500.15 65999...  0.1
# 3   4  6.231998  POLYGON ((249532.25 659999.27, 249531.81 65999...  0.1
# 4   5  4.015003  POLYGON ((249982.75 659999.27, 249982.31 65999...  0.1

# %%
combined_gdf["G"].unique()
# Out:
# array([0.1, 0.9])

# %%
subset = gpd.clip(combined_gdf, bbox)

# %%
subset.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1915f2df86ccb88f69cd0143d0d2181a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1915f2df86ccb88f69cd0143d0d2181a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1915f2df86ccb88f69cd0143d0d2181a = L.map(
#                 &quot;map_1915f2df86ccb88f69cd0143d0d2181a&quot;,
#                 {
#                     center: [55.8245626108213, -4.331876490095715],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_1915f2df86ccb88f69cd0143d0d2181a);
#
#
#
#
#
#             var tile_layer_2b3afd5b4de2db5fc1c7a286ebfa6e10 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b3afd5b4de2db5fc1c7a286ebfa6e10.addTo(map_1915f2df86ccb88f69cd0143d0d2181a);
#
#
#             map_1915f2df86ccb88f69cd0143d0d2181a.fitBounds(
#                 [[55.82008523229814, -4.341405383297268], [55.82903998934446, -4.322347596894163]],
#                 {}
#             );
#
#
#         function geo_json_f8ebb7ab1b1d1a16460f40b4563d8ead_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f8ebb7ab1b1d1a16460f40b4563d8ead_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f8ebb7ab1b1d1a16460f40b4563d8ead_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_f8ebb7ab1b1d1a16460f40b4563d8ead_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f8ebb7ab1b1d1a16460f40b4563d8ead_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_f8ebb7ab1b1d1a16460f40b4563d8ead.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f8ebb7ab1b1d1a16460f40b4563d8ead_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f8ebb7ab1b1d1a16460f40b4563d8ead = L.geoJson(null, {
#                 onEachFeature: geo_json_f8ebb7ab1b1d1a16460f40b4563d8ead_onEachFeature,
#
#                 style: geo_json_f8ebb7ab1b1d1a16460f40b4563d8ead_styler,
#                 pointToLayer: geo_json_f8ebb7ab1b1d1a16460f40b4563d8ead_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_f8ebb7ab1b1d1a16460f40b4563d8ead_add (data) {
#             geo_json_f8ebb7ab1b1d1a16460f40b4563d8ead
#                 .addData(data);
#         }
#             geo_json_f8ebb7ab1b1d1a16460f40b4563d8ead_add({&quot;bbox&quot;: [-4.341405383297268, 55.82008523229814, -4.322347596894163, 55.82903998934446], &quot;features&quot;: [{&quot;bbox&quot;: [-4.324710615590456, 55.82027820558242, -4.324678616385359, 55.82029622079745], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-4.324682914128563, 55.820281053262484], [-4.324695675158017, 55.82027820558242], [-4.324705557528613, 55.82028062512722], [-4.324710615590456, 55.82028780943081], [-4.324706317850562, 55.82029337311622], [-4.324693556816918, 55.82029622079745], [-4.324683674443015, 55.82029380125175], [-4.324678616385359, 55.82028661694699], [-4.324682914128563, 55.820281053262484]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;5

# %%
len(combined_gdf)
# Out:
# 1401054

# %%
combined_gdf.columns
# Out:
# Index(['PK', 'HEIGHT', 'geometry', 'G'], dtype='object')

# %%
combined_gdf = combined_gdf.drop(columns=['PK'])

# %%
combined_gdf = combined_gdf[['HEIGHT', 'geometry', 'G']].rename(columns={'HEIGHT': 'HEIGHT', 'geometry': 'THE_GEOM', 'G': 'G'})

# %%
combined_gdf.columns
# Out:
# Index(['HEIGHT', 'THE_GEOM', 'G'], dtype='object')

# %%
# Changing geometry names to match case with noisemodelling 
combined_gdf = combined_gdf.set_geometry("THE_GEOM")
# Save as a geojson, note that this is now a 27700
combined_gdf.to_file(r"C:\Users\ibk1\NoiseModelling\Glasgow\noisemodelling_outputs\Round3\trees_final_4.geojson", driver="GeoJSON")

# %% [markdown]
# # Edinburgh Trees and Buildings
# Data: https://data.edinburghcouncilmaps.info/datasets/6c224ada230b4d349cfd739015c7846d_41/explore

# %% [markdown]
# #### buildings layer
# Acquired from OpenStreetMap

# %%
import geopandas as gpd
import pandas as pd

# %%
nm_edi_buildings = gpd.read_file(r"C:\Users\ibk1\NoiseModelling\Edinburgh\noisemodelling_inputs\buildings\nm_edi_buildings.geojson")

# %% [markdown]
# #### setting buildings wall abs to 0.9

# %%
nm_edi_buildings["G"] = 0.9 # Adding wall absorption

# %%
nm_edi_buildings.head()
# Out:
#            PK    HEIGHT                                           geometry
# 0  1308683759  6.877683  POLYGON ((329067.092 667684.922, 329073.301 66...  \
# 1  1308683758  7.579757  POLYGON ((329060.026 667693.855, 329066.235 66...
# 2  1308683757  6.453828  POLYGON ((329054.707 667703.248, 329060.916 66...
# 3  1308683760  6.077773  POLYGON ((329087.424 667703.825, 329093.633 66...
# 4  1308683761  6.119651  POLYGON ((329082.493 667713.958, 329088.701 66...
#
#      G
# 0  0.9
# 1  0.9
# 2  0.9
# 3  0.9
# 4  0.9

# %% [markdown]
# #### reading trees shapefiles

# %%
editrees_buff = gpd.read_file(r"C:\Users\ibk1\NoiseModelling\Edinburgh\env_data\Trees\Trees.shp")

# %%
len(editrees_buff)
# Out:
# 50400

# %%
editrees_buff["
# Out:
# Index(['OBJECTID', 'PrimaryKey', 'LocationOr', 'Ward', 'Site', 'LatinName',
#        'CommonName', 'Owner', 'NTRef', 'Height', 'Spread', 'AgeGroup',
#        'DiameterAt', 'Easting', 'Northing', 'geometry'],
#       dtype='object')

# %% [markdown]
# #### setting tree values to mid range, setting wall abs to 0.1

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point

height_mapping = {
    "5 to 10 meters": 7.5,
    "10 to 15 meters": 12.5,
    "15 to 20 meters": 17.5,
    "20 to 25 meters": 22.5,
    "25 to 30 meters": 27.5,
    "Up to 5 meters": 4.5,
    "30 meters +": 32,
}

# Function to map height values
def extract_height(value):
    if pd.isna(value) or value is None:
        return None  # Keep NaN values

    value = str(value).strip()  # Convert to string and remove extra spaces
    
    if value in height_mapping:
        return height_mapping[value]  # Use predefined mapping
    
    return None  # If value is not found in mapping, return NaN
# Apply functions to extract values
editrees_buff["HEIGHT"] = editrees_buff["Height"].apply(extract_height)  # Tree height (meters)
editrees_buff["G"] = .1 # Wall absorption

# %%
editrees_buff["HEIGHT"].describe()
# Out:
# count    49996.000000
# mean        10.097528
# std          5.501568
# min          4.500000
# 25%          4.500000
# 50%          7.500000
# 75%         12.500000
# max         32.000000
# Name: HEIGHT, dtype: float64

# %% [markdown]
# #### creating geometry buffer of 1 meter
# setting avg height for nan to 5 m

# %%
editrees_buff["geometry"] = editrees_buff.geometry.buffer(1)
editrees_buff['HEIGHT'] = editrees_buff['HEIGHT'].fillna(5)

# %% [markdown]
# #### combining trees and nm buildings

# %%
# Combine both GeoDataFrames
merged_gdf_buff = gpd.GeoDataFrame(pd.concat([editrees_buff, nm_edi_buildings], ignore_index=True))

# Ensure it remains a GeoDataFrame and retains geometries
merged_gdf_buff = gpd.GeoDataFrame(merged_gdf_buff, geometry="geometry", crs="EPSG:27700")

# %%
print(len(nm_edi_buildings), len(editrees_buff), len(merged_gdf_buff))
# Out:
# 158826 50400 209226

# %%
merged_gdf_buff.head()
# Out:
#    OBJECTID         PrimaryKey LocationOr                            Ward
# 0       1.0     Grp/1 (845800)       None                    Inverleith\n  \
# 1       2.0   Sgl/358 (813204)   2-205-16  Fountainbridge/Craiglockhart\n
# 2       3.0    Sgl/18 (046468)     b05936                Drum Brae/Gyle\n
# 3       4.0  Sgl/1274 (071816)     g00495                        Almond\n
# 4       5.0    Sgl/82 (193348)       w765                        Almond\n
#
#                       Site            LatinName CommonName
# 0  Raeburn Mews, Edinburgh                 None       None  \
# 1      Craiglockhart Woods                 None       None
# 2  Rannoch Road, Edinburgh  Acer pseudoplatanus   Sycamore
# 3   Davidson's Main's Park  Acer pseudoplatanus   Sycamore
# 4        Royal High School  Acer pseudoplatanus   Sycamore
#
#                    Owner           NTRef           Height          Spread
# 0                   None  NT06-9001-0993             None            None  \
# 1    Culture and Leisure  NT06-9010-1010   5 to 10 meters   6 to 9 meters
# 2                   None  NT17-0000-4261  15 to 20 meters  Over 12 meters
# 3    Culture and Leisure  NT17-0000-5419  20 to 25 meters  Over 12 meters
# 4  Children and Families  NT17-0000-5184  15 to 20 meters  9 to 12 meters
#
#       AgeGroup DiameterAt   Easting  Northing
# 0  Over-Mature       None  309001.0  660993.0  \
# 1     Juvenile    10 - 20  309010.0  661010.0
# 2       Mature       90 +  310000.0  674261.0
# 3       Mature       90 +  310000.0  675419.0
# 4       Mature    50 - 60  310000.0  675184.0
#
#                                             geometry  HEIGHT    G  PK
# 0  POLYGON ((309002 660993, 309001.995 660992.902...     5.0  0.1 NaN
# 1  POLYGON ((309011 661010, 309010.995 661009.902...     7.5  0.1 NaN
# 2  POLYGON ((310001 674261, 310000.995 674260.902...    17.5  0.1 NaN
# 3  POLYGON ((310001 675419, 310000.995 675418.902...    22.5  0.1 NaN
# 4  POLYGON ((310001 675184, 310000.995 675183.902...    17.5  0.1 NaN

# %% [markdown]
# #### subsetting to relevant fields

# %%
keep_col = ["HEIGHT", "geometry", "G"]
# Keep only the relevant columns
merged_gdf_buff = merged_gdf_buff[keep_col]

# %%
merged_gdf_buff.head()
# Out:
#    HEIGHT                                           geometry    G
# 0     5.0  POLYGON ((309002 660993, 309001.995 660992.902...  0.1
# 1     7.5  POLYGON ((309011 661010, 309010.995 661009.902...  0.1
# 2    17.5  POLYGON ((310001 674261, 310000.995 674260.902...  0.1
# 3    22.5  POLYGON ((310001 675419, 310000.995 675418.902...  0.1
# 4    17.5  POLYGON ((310001 675184, 310000.995 675183.902...  0.1

# %%
merged_gdf_buff["PK"] = range(1, len(merged_gdf_buff)+1)

# %%
merged_gdf_buff
# Out:
#            HEIGHT                                           geometry    G
# 0        5.000000  POLYGON ((309002 660993, 309001.995 660992.902...  0.1  \
# 1        7.500000  POLYGON ((309011 661010, 309010.995 661009.902...  0.1
# 2       17.500000  POLYGON ((310001 674261, 310000.995 674260.902...  0.1
# 3       22.500000  POLYGON ((310001 675419, 310000.995 675418.902...  0.1
# 4       17.500000  POLYGON ((310001 675184, 310000.995 675183.902...  0.1
# ...           ...                                                ...  ...
# 209221   5.272708  POLYGON ((312156.643 678821.294, 312167.928 67...  0.9
# 209222   5.211208  POLYGON ((312958.545 678399.613, 312964.718 67...  0.9
# 209223   4.077840  POLYGON ((313674.709 678398.168, 313670.064 67...  0.9
# 209224   5.441919  POLYGON ((313682.199 678399.765, 313676.993 67...  0.9
# 209225   4.813933  POLYGON ((312944.677 678407.208, 312947.843 67...  0.9
#
#             PK
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ...        ...
# 209221  209222
# 209222  209223
# 209223  209224
# 209224  209225
# 209225  209226
#
# [209226 rows x 4 columns]

# %%
merged_gdf_buff.to_file(r"C:\Users\ibk1\NoiseModelling\Edinburgh\noisemodelling_outputs\Round 6\buildings9_trees1_pk.geojson", driver="geoJSON")
